# %%
import pandas as pd
dataset=pd.read_csv("Downloads/archive/iris.csv")
dataset.head(150)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
n_num = [3.5,3.0,3.2,3.1,3.6]
n = len(n_num)
get_sum = sum(n_num)
mean = get_sum / n
print("Mean / Average is: " + str(mean))
# Out:
# Mean / Average is: 3.28

# %%
n_num = [3.5,3.0,3.2,3.1,3.6]
n = len(n_num)
n_num.sort()
if n % 2 == 0:
    median1 = n_num[n//2]
    median = (median1 + median2)/2
else:
    median = n_num[n//2]
    print("Median is: " + str(median))
# Out:
# Median is: 3.2

# %%
from collections import Counter
n_num=[3.5,3.0,3.2,3.1,3.6]
n=len(n_num)
data=Counter(n_num)
get_mode=dict(data)
mode=[k for k, v in get_mode.items() if v==max(list(data.values()))]
if len(mode)==n:
    get_mode="No mode found"
else:
    get_mode="Mode is / are: " + ', '.join(map(str, mode))
print(get_mode)
# Out:
# No mode found

# %%
import pandas as pd
import matplotlib.pyplot as plot
dataset=pd.read_csv("Downloads/archive/iris.csv")
b_plot=dataset.boxplot(column=['sepal_length','sepal_width','petal_length','petal_width'])
b_plot.plot()
plot.show()

# %%
import pandas as pd
import matplotlib.pyplot as plot
dataset=pd.read_csv("Downloads/archive/iris.csv")
b_plot=dataset.boxplot(column=['sepal_length'])
b_plot.plot()
plot.show()

# %%
import pandas as pd
dataset=pd.read_csv("Downloads/toyota/ToyotaCorolla.csv")
dataset.head(150)
# Out:
#       Id                                              Model  Price  Age_08_04  \
# 0      1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1      2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2      3     ?TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3      4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4      5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
# ..   ...                                                ...    ...        ...
# 145  147  ?TOYOTA Corolla 1.4 16V VVT I 5DR TERRA 4/5-Doors  16450         16
# 146  148  ?TOYOTA Corolla 1.6 16V VVT I 5DR TERRA COMF A...  20500         20
# 147  149  TOYOTA Corolla 1.6 16V VVT I 5DR EXEC BNS 4/5-...  24500         13
# 148  150     TOYOTA Corolla 1.6 16V VVT I 5DR SOL 4/5-Doors  19450         19
# 149  151  TOYOTA Corolla 1.6 16V VVT I SEDAN SOL AUT4 4/...  20950         14
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plot
dataset=pd.read_csv(r"C:\Users\tapas\Downloads\toyota\ToyotaCorolla.csv")
histogram=dataset.hist(column=['Price','Age_08_04','Mfg_Month','Mfg_Year','KM','Fuel_Type','HP','Met_Color','Central_Lock'])
plot.show()

# %%
import pandas as pd
import matplotlib.pyplot as plot
dataset=pd.read_csv(r"C:\Users\tapas\Downloads\toyota\ToyotaCorolla.csv")
dataset.plot(kind='scatter',x='Age_08_04',y='price')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
